# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы ГРУППА ФИО

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)
# 4. [Вывод](#Вывод)

# %% [markdown]
# ### Задание №1
# <i> Вызвать функцию print() и передать туда строку Hello, World! </i>

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц(многомерных), который принимает
# опциональные параметры <b>m</b>, <b>n</b>, <b>min_limit</b>, <b>max_limit</b>, где <b>m</b> и <b>n</b> указывают размер
# матрицы, а <b>min_lim</b> и <b>max_lim</b> - минимальное и максимальное значение для
# генерируемого числа.

# %%
import random
import time

# %%
import random
user_m = input("m =")
user_n = input("n =")
user_min_limit = input("min_lim =")
user_max_limit = input("max_lim =")
#user_m, user_n, user_min_limit, user_max_limit
Matr = [[random.randint(int(user_min_limit),int(user_max_limit)) for j in range(int(user_n))] for i in range(int(user_m)) ]

for i in range(int(user_m)):
    print(Matr[i])
# Out:
# [7, 5, 8, 7, 10]
# [5, 6, 5, 8, 9]
# [7, 9, 10, 5, 6]
# [7, 6, 10, 9, 8]
# [6, 10, 10, 5, 9]

# %% [markdown]
# ### Задание №3
# Реализовать методы сортировки строк числовой матрицы в соответствии с
# заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со
# временем стандартной функции сортировки. Испытания проводить на сгенерированных
# матрицах.

# %%
import copy
import time
#Cортировка с помощью стандартной сортировки
start_time = time.time()
#TODO


n = 30
m = 30
min_lim = 100
max_lim = 999
Matr = [[random.randint(int(min_lim),int(max_lim)) for j in range(int(n))] for i in range(int(m)) ]

for i in range(int(m)):
    print(sorted(Matr[i]))

print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# [134, 157, 194, 207, 230, 230, 240, 270, 278, 335, 349, 442, 451, 464, 476, 492, 502, 624, 626, 670, 712, 722, 724, 765, 769, 795, 846, 902, 952, 990]
# [148, 178, 219, 234, 274, 313, 369, 387, 388, 395, 460, 467, 529, 568, 575, 580, 616, 632, 640, 641, 666, 753, 764, 764, 774, 797, 808, 894, 898, 974]
# [135, 203, 262, 267, 269, 318, 399, 408, 422, 423, 424, 430, 445, 455, 481, 591, 608, 664, 680, 703, 705, 705, 708, 780, 786, 835, 840, 847, 964, 965]
# [101, 110, 124, 125, 170, 186, 200, 209, 298, 339, 370, 407, 423, 480, 497, 518, 552, 573, 606, 638, 652, 706, 739, 751, 770, 887, 904, 912, 933, 963]
# [126, 150, 196, 217, 240, 298, 332, 354, 355, 365, 377, 402, 445, 480, 519, 521, 529, 557, 655, 726, 726, 733, 775, 799, 817, 860, 893, 896, 911, 996]
# [106, 138, 144, 159, 166, 192, 227, 339, 343, 378, 455, 455, 489, 609, 633, 671, 718, 721, 734, 743, 793, 812, 815, 854, 856, 861, 896, 941, 950, 974]
# ...

# %%
import time
# Сортировка выбором.
# Берётся срез массива, в котором минимальный элемент переносят в самый левый угол,
# после чего срез уменьшается и цикл повторяется.
start_time = time.time()
#TODO
def func_choice(Matr):
    for i in range(0, len(Matr) - 1):
        minim = i
        for j in range(i + 1, len(Matr)):
            if Matr[j] < Matr[minim]:
                minim = j
        Matr[i], Matr[minim] = Matr[minim], Matr[i]
    return(Matr)

n = 30
m = 30
min_lim = 100
max_lim = 999

Matr = [[random.randint(int(min_lim),int(max_lim)) for j in range(int(n))] for i in range(int(m)) ]

for i in range(int(m)):
    print(func_choice(Matr[i]))

print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# [104, 105, 179, 191, 245, 252, 285, 304, 318, 374, 473, 514, 531, 575, 598, 629, 680, 683, 705, 716, 754, 755, 777, 857, 868, 907, 925, 939, 956, 989]
# [103, 140, 154, 189, 248, 250, 263, 304, 323, 330, 337, 357, 372, 380, 402, 418, 428, 434, 480, 501, 505, 669, 694, 803, 809, 812, 895, 904, 907, 914]
# [180, 196, 281, 283, 373, 375, 416, 482, 495, 508, 530, 543, 572, 648, 670, 697, 737, 750, 771, 775, 811, 827, 840, 871, 878, 891, 899, 929, 988, 996]
# [119, 120, 148, 164, 183, 208, 284, 290, 315, 352, 354, 363, 462, 464, 531, 574, 580, 644, 656, 687, 739, 801, 817, 829, 833, 856, 907, 908, 985, 992]
# [107, 131, 192, 208, 214, 285, 318, 327, 380, 396, 446, 477, 488, 491, 516, 544, 546, 587, 622, 631, 725, 806, 815, 852, 855, 860, 873, 880, 918, 997]
# [141, 145, 156, 166, 169, 182, 194, 200, 205, 258, 260, 279, 388, 404, 435, 488, 503, 505, 518, 531, 553, 611, 725, 744, 762, 821, 849, 863, 913, 986]
# ...

# %%
import time
# Сортировка вставкой.
start_time = time.time()
#TODO
def func_insert(Matr):
    for i in range(len(Matr)):
        cursor = Matr[i]
        pos = i
        
        while pos > 0 and Matr[pos - 1] > cursor:
            # Меняем местами число, продвигая по списку
            Matr[pos] = Matr[pos - 1]
            pos = pos - 1
        # Остановимся и сделаем последний обмен
        Matr[pos] = cursor
    return(Matr)

n = 30
m = 30
min_lim = 100
max_lim = 999

Matr = [[random.randint(int(min_lim),int(max_lim)) for j in range(int(n))] for i in range(int(m)) ]

for i in range(int(m)):
    print(func_choice(Matr[i]))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# [105, 149, 151, 233, 242, 270, 296, 300, 311, 354, 358, 359, 365, 396, 473, 475, 477, 482, 555, 586, 591, 613, 673, 688, 694, 891, 897, 917, 953, 968]
# [105, 126, 127, 165, 214, 218, 230, 231, 273, 274, 339, 370, 371, 375, 474, 477, 591, 602, 615, 665, 672, 688, 725, 821, 845, 847, 930, 948, 975, 981]
# [112, 165, 190, 209, 242, 266, 304, 338, 343, 440, 483, 573, 589, 607, 625, 625, 626, 647, 671, 682, 683, 712, 733, 753, 786, 849, 862, 931, 972, 982]
# [129, 146, 150, 150, 155, 175, 204, 235, 242, 252, 273, 289, 296, 310, 314, 337, 426, 457, 482, 598, 632, 634, 668, 676, 731, 791, 801, 812, 877, 991]
# [187, 189, 211, 223, 259, 304, 344, 361, 421, 519, 527, 544, 569, 573, 577, 627, 671, 679, 681, 696, 723, 801, 822, 830, 838, 855, 914, 940, 951, 993]
# [124, 189, 196, 237, 269, 337, 342, 364, 391, 398, 403, 407, 417, 420, 442, 569, 577, 611, 621, 624, 629, 723, 779, 815, 830, 877, 882, 932, 950, 958]
# ...

# %%
import time
# Сортировка обменом. || Сортировка пузырьком.
start_time = time.time()
#TODO
def bubble_sort(Matr):
    def swap(i, j):
        Matr[i], Matr[j] = Matr[j], Matr[i]

    n = len(Matr)
    swapped = True
    
    x = -1
    while swapped:
        swapped = False
        x = x + 1
        for i in range(1, n-x):
            if Matr[i - 1] > Matr[i]:
                swap(i - 1, i)
                swapped = True
    return(Matr)

n = 30
m = 30
min_lim = 100
max_lim = 999

Matr = [[random.randint(int(min_lim),int(max_lim)) for j in range(int(n))] for i in range(int(m)) ]

for i in range(int(m)):
    print(bubble_sort(Matr[i]))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# [104, 129, 219, 241, 275, 275, 288, 299, 300, 310, 393, 395, 404, 406, 420, 434, 446, 496, 514, 538, 552, 583, 665, 768, 787, 790, 804, 949, 988, 997]
# [171, 198, 228, 273, 291, 292, 298, 328, 369, 378, 386, 465, 476, 515, 539, 543, 576, 577, 590, 632, 647, 700, 714, 748, 771, 822, 823, 835, 955, 956]
# [198, 204, 218, 287, 290, 299, 324, 332, 343, 362, 374, 377, 390, 448, 501, 556, 606, 652, 761, 787, 838, 859, 890, 905, 931, 950, 962, 973, 977, 978]
# [111, 132, 199, 221, 266, 297, 303, 315, 332, 350, 359, 368, 398, 437, 489, 501, 514, 536, 593, 621, 665, 764, 795, 799, 804, 819, 862, 891, 909, 989]
# [123, 158, 223, 240, 273, 285, 292, 311, 354, 405, 466, 493, 535, 543, 567, 599, 620, 633, 645, 671, 682, 786, 824, 831, 872, 874, 888, 894, 983, 987]
# [119, 182, 186, 192, 209, 265, 268, 329, 335, 339, 351, 352, 374, 377, 402, 434, 438, 462, 463, 521, 552, 560, 594, 615, 660, 713, 722, 729, 969, 995]
# ...

# %%
import time
# Сортировка Шелла.
start_time = time.time()
#TODO
import math

def shellSort(array):
    n = len(array)
    k = int(math.log2(n))
    interval = 2**k -1
    while interval > 0:
        for i in range(interval, n):
            temp = array[i]
            j = i
            while j >= interval and array[j - interval] > temp:
                array[j] = array[j - interval]
                j -= interval
            array[j] = temp
        k -= 1
        interval = 2**k -1
    return array

n = 30
m = 30
min_lim = 100
max_lim = 999

Matr = [[random.randint(int(min_lim),int(max_lim)) for j in range(int(n))] for i in range(int(m)) ]

for i in range(int(m)):
    print(shellSort(Matr[i]))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# [146, 152, 171, 190, 198, 231, 272, 283, 321, 341, 377, 400, 556, 605, 636, 661, 667, 704, 718, 725, 729, 742, 763, 765, 781, 812, 858, 953, 955, 994]
# [132, 133, 210, 258, 259, 308, 340, 380, 406, 414, 457, 460, 485, 487, 509, 554, 589, 710, 749, 760, 777, 803, 823, 826, 851, 853, 945, 981, 991, 997]
# [101, 134, 194, 197, 228, 240, 255, 360, 418, 419, 511, 516, 523, 542, 547, 551, 610, 614, 633, 638, 676, 696, 723, 749, 827, 866, 891, 937, 938, 985]
# [116, 135, 204, 213, 288, 338, 356, 417, 434, 470, 480, 489, 492, 526, 561, 563, 567, 595, 595, 699, 711, 724, 733, 771, 837, 845, 890, 930, 974, 993]
# [129, 136, 142, 164, 227, 244, 258, 281, 339, 360, 387, 399, 409, 435, 437, 500, 532, 543, 591, 595, 627, 717, 762, 861, 878, 883, 911, 943, 970, 985]
# [114, 121, 121, 158, 187, 363, 372, 380, 402, 419, 437, 483, 504, 504, 524, 536, 583, 584, 591, 593, 596, 619, 622, 727, 877, 910, 928, 962, 980, 991]
# ...

# %%
# Быстрая сортировка.
import time
start_time = time.time()
#TODO
def quickSort(array):
    if len(array)> 1:
        pivot=array.pop()
        grtr_lst, equal_lst, smlr_lst = [], [pivot], []
        for item in array:
            if item == pivot:
                equal_lst.append(item)
            elif item > pivot:
                grtr_lst.append(item)
            else:
                smlr_lst.append(item)
        return (quickSort(smlr_lst) + equal_lst + quickSort(grtr_lst))
    else:
        return array

n = 30
m = 30
min_lim = 100
max_lim = 999

Matr = [[random.randint(int(min_lim),int(max_lim)) for j in range(int(n))] for i in range(int(m)) ]

for i in range(int(m)):
    print(quickSort(Matr[i]))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# [106, 113, 172, 186, 277, 305, 330, 372, 390, 467, 487, 498, 589, 658, 670, 678, 710, 712, 764, 765, 771, 816, 875, 890, 899, 920, 940, 964, 993, 993]
# [108, 110, 111, 184, 233, 258, 276, 278, 340, 437, 437, 437, 480, 498, 595, 609, 630, 653, 690, 693, 704, 706, 708, 738, 771, 781, 835, 838, 896, 935]
# [102, 151, 159, 167, 187, 187, 311, 320, 449, 485, 575, 603, 610, 628, 632, 670, 671, 715, 765, 790, 806, 832, 835, 872, 900, 931, 933, 947, 948, 973]
# [108, 239, 248, 358, 420, 442, 445, 458, 458, 475, 518, 522, 581, 632, 658, 659, 660, 667, 682, 709, 715, 747, 783, 871, 881, 888, 891, 915, 948, 995]
# [130, 132, 159, 159, 192, 219, 231, 297, 311, 320, 324, 332, 334, 362, 365, 435, 491, 517, 560, 565, 593, 622, 629, 653, 698, 739, 786, 870, 951, 970]
# [106, 106, 134, 136, 148, 194, 271, 296, 311, 401, 422, 434, 443, 549, 628, 652, 724, 727, 788, 794, 799, 836, 837, 844, 847, 849, 916, 930, 937, 989]
# ...

# %%
# Турнирная сортировка.
import time
start_time = time.time()
#TODO
def tournament_sort(a: list[int]) -> list[int]:
    a_len: int = len(a)
    heap = PriorityHeap()
    winners: list[int] = []
    losers: list[int] = []

    while heap.size < heap.max_size and heap.size < a_len:
        elem = a[heap.size]
        if winners and winners[-1] > elem:
            losers.append(elem)
        else:
            heap.max_heap_insert(a[heap.size])

    for i in range(heap.size, a_len):
        elem: int = a[i]

        if winners and winners[-1] > elem:
            losers.append(elem)
        else: 
            max_elem: int = heap.pop_max()

            if not winners:
                winners.append(max_elem)
            elif winners[-1] <= max_elem:
                winners.append(max_elem)
            else:
                losers.append(max_elem)

            heap.max_heap_insert(elem)
    
    while heap.size > 0:
        max_elem: int = heap.pop_max()

        if not winners:
            winners.append(max_elem)
        elif winners[-1] <= max_elem:
            winners.append(max_elem)
        else: 
            losers.append(max_elem)
    
    if not losers:
        return winners
    else:
        winners2: list[int] = tournament_sort(losers)

        i: int = 0
        j: int = 0
        winners1_len: int = len(winners)
        winners2_len: int = len(winners2)

        winners_res: list[int] = []

        while i < winners1_len and j < winners2_len:
            if winners[i] < winners2[j]:
                winners_res.append(winners[i])
                i += 1
            else:
                winners_res.append(winners2[j])
                j += 1
        while i < winners1_len:
            winners_res.append(winners[i])
            i += 1
        while j < winners2_len:
            winners_res.append(winners2[j])
            j += 1
        return winners_res

class PriorityHeap:
    def __init__(self) -> None:
        self.cache: list[int] = []
        self.size: int = 0
        self.max_size = 32

    def pop_max(self) -> any: ###
        res = self.cache[0]
        self.size -= 1
        self.cache[0] = self.cache[self.size]
        self.cache.pop(self.size)
        self.iter_heapify(0)
        return res

    def max_heap_insert(self, key: int):
        self.cache.append(-1000000000000000)
        self.insert_key(key, self.size)       #iter_key
        self.size += 1
        
    def insert_key(self, value: int, i: int):
        self.cache[i]  = value
        parent = self.parent(i)
        while i > 0 and self.cache[parent] > self.cache[i]:
            self.cache[parent], self.cache[i] = self.cache[i], self.cache[parent]
            i = parent
            parent = self.parent(i)

    def parent(self, i: int) -> int:
        res = (i >> 1) - 1
        if res < 0:
            return 0
        else:
            return res

    def iter_heapify(self, i: int) -> None:
        while True:
            l: int = (i << 1) + 1
            r: int = (i << 1) + 2
            largest: int = i

            if l < self.size and self.cache[l] < self.cache[largest]:
                largest = l

            if r < self.size and self.cache[r] < self.cache[largest]:
                largest = r

            if largest ==i:
                break
            else:
                self.cache[i], self.cache[largest] = self.cache[largest], self.cache[i]
                i = largest




n = 30
m = 30
min_lim = 100
max_lim = 999


Matr = [[random.randint(int(min_lim),int(max_lim)) for j in range(int(n))] for i in range(int(m)) ]

for i in range(int(m)):
    print(tournament_sort(Matr[i]))
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# [105, 121, 126, 188, 205, 211, 248, 264, 289, 291, 327, 329, 395, 430, 432, 436, 496, 559, 654, 711, 728, 745, 751, 802, 824, 905, 910, 911, 974, 979]
# [113, 140, 145, 155, 155, 264, 265, 293, 314, 335, 341, 368, 401, 427, 440, 460, 487, 508, 526, 569, 575, 599, 610, 633, 646, 648, 808, 856, 913, 953]
# [114, 128, 136, 165, 181, 204, 204, 285, 290, 294, 307, 337, 382, 412, 422, 432, 477, 483, 598, 610, 619, 675, 790, 793, 806, 814, 826, 906, 931, 948]
# [109, 132, 135, 249, 272, 283, 299, 357, 376, 508, 517, 518, 522, 527, 549, 553, 581, 674, 690, 789, 790, 790, 802, 810, 873, 878, 890, 907, 970, 987]
# [117, 124, 157, 201, 238, 273, 276, 278, 321, 415, 416, 437, 444, 460, 473, 563, 586, 600, 650, 688, 704, 770, 771, 773, 788, 796, 838, 850, 948, 949]
# [111, 150, 171, 178, 191, 218, 264, 285, 328, 385, 389, 413, 417, 472, 480, 547, 563, 596, 617, 638, 674, 718, 814, 837, 841, 915, 934, 959, 966, 991]
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# В данной лабораторной работе мы научились не только выводить Hello, world но и провели анализ сортировок таких как:
# стандартная сортировка python(--- 2 ms ---)
# сортировка выбором(--- 5 ms ---)
# сортировка вставкой(--- 3 ms ---)
# сортировка пузырьком(--- 5 ms ---)
# сортировка Шелла(--- 4 ms ---)
# быстрой сортировкой(--- 4 ms ---)
# турнирной сортировкой(--- 10 ms ---)
# Исходя из временных результатов можно с уверенностью полагать, что стандартная сортировка показала лучший результат,
# Так же хорошо себя показала сортировка вставкой.
# Помимо реализации сортировок мы научились генерировать рандомные матрицы используя random
